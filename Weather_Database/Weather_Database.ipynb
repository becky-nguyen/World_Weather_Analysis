# %%
#import dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import requests
from citipy import citipy
from config import weather_api_key
import time
from datetime import datetime

# %%
#create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000,high=90.000,size=2000)
lngs = np.random.uniform(low=-180.000,high=180.000,size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
#add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %%
#create a list for holding the cities.
cities = []
#identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    #if the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
#print the city count to confirm sufficient count.
len(cities)
# Out:
# 735

# %%
#create an empty list to hold the weather data
city_data = []
#print the beginning of the logging
print("Beginning Data Retrievel                                            ")
print("--------------------------------------------------------------------")

#create counters
record_count = 1
set_count = 1

#starting URL for weather map API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
# Out:
# Beginning Data Retrievel
# --------------------------------------------------------------------

# %%
#loop through all the cities in our list
for i, city in enumerate(cities):
    #group cities in sets of 50 for logging purposes:
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)
    #create endpoint url with each city
    city_url = url + "&q=" + city.replace(" ","+")
    #log the url, record, and set numbers and the city
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    #add 1 to the record count
    record_count += 1
#run an api request for each of the cities
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | iralaya
# Processing Record 2 of Set 1 | hithadhoo
# Processing Record 3 of Set 1 | rungata
# City not found. Skipping...
# Processing Record 4 of Set 1 | port alfred
# Processing Record 5 of Set 1 | krasnoselkup
# Processing Record 6 of Set 1 | kapaa
# Processing Record 7 of Set 1 | guarapari
# Processing Record 8 of Set 1 | bluff
# Processing Record 9 of Set 1 | egvekinot
# Processing Record 10 of Set 1 | rikitea
# Processing Record 11 of Set 1 | albany
# Processing Record 12 of Set 1 | stephenville
# Processing Record 13 of Set 1 | minab
# Processing Record 14 of Set 1 | port elizabeth
# Processing Record 15 of Set 1 | guerrero negro
# Processing Record 16 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 17 of Set 1 | hermanus
# Processing Record 18 of Set 1 | cabo san lucas
# Processing Record 19 of Set 1 | bambous virieux
# Processing Record 20 of Set 1 | qaanaaq
# Processing Record 21 of Set 1 | pangai
# Processing Record 22 of Set 1 | luderitz
# Processing Record 23 of Set 1 | solnechnyy
# Processing Record 24 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 25 of Set 1 | ushuaia
# Processing Record 26 of Set 1 | tasiilaq
# Processing Record 27 of Set 1 | sao geraldo do araguaia
# Processing Record 28 of Set 1 | alotau
# City not found. Skipping...
# Processing Record 29 of Set 1 | ust-maya
# Processing Record 30 of Set 1 | busselton
# Processing Record 31 of Set 1 | hofn
# Processing Record 32 of Set 1 | natal
# Processing Record 33 of Set 1 | tabiauea
# City not found. Skipping...
# Processing Record 34 of Set 1 | ribeira grande
# Processing Record 35 of Set 1 | rawannawi
# City not found. Skipping...
# Processing Record 36 of Set 1 | severo-kurilsk
# Processing Record 37 of Set 1 | garden city
# Processing Record 38 of Set 1 | longyearbyen
# Processing Record 39 of Set 1 | puerto ayora
# Processing Record 40 of Set 1 | westport
# Processing Record 41 of Set 1 | mnogovershinnyy
# Processing Record 42 of Set 1 | oytal
# Processing Record 43 of Set 1 | dunedin
# Processing Record 44 of Set 1 | carnarvon
# Processing Record 45 of Set 1 | punta arenas
# Processing Record 46 of Set 1 | barrow
# Processing Record 47 of Set 1 | hay river
# Processing Record 48 of Set 1 | siocon
# Processing Record 49 of Set 1 | new norfolk
# Processing Record 50 of Set 1 | narsaq
# Processing Record 1 of Set 2 | vostok
# Processing Record 2 of Set 2 | kodiak
# Processing Record 3 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 4 of Set 2 | correntina
# Processing Record 5 of Set 2 | georgetown
# Processing Record 6 of Set 2 | hervey bay
# Processing Record 7 of Set 2 | ilulissat
# Processing Record 8 of Set 2 | kirakira
# Processing Record 9 of Set 2 | bathsheba
# Processing Record 10 of Set 2 | west wendover
# Processing Record 11 of Set 2 | kruisfontein
# Processing Record 12 of Set 2 | lorengau
# Processing Record 13 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 14 of Set 2 | sorong
# Processing Record 15 of Set 2 | cheney
# Processing Record 16 of Set 2 | esperance
# Processing Record 17 of Set 2 | butaritari
# Processing Record 18 of Set 2 | adre
# Processing Record 19 of Set 2 | erzurum
# Processing Record 20 of Set 2 | bagdarin
# Processing Record 21 of Set 2 | lasa
# Processing Record 22 of Set 2 | lamu
# Processing Record 23 of Set 2 | axim
# Processing Record 24 of Set 2 | billings
# Processing Record 25 of Set 2 | yellowknife
# Processing Record 26 of Set 2 | ancud
# Processing Record 27 of Set 2 | mataura
# Processing Record 28 of Set 2 | nishihara
# Processing Record 29 of Set 2 | narrabri
# Processing Record 30 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 31 of Set 2 | novyy nekouz
# Processing Record 32 of Set 2 | nuuk
# Processing Record 33 of Set 2 | upernavik
# Processing Record 34 of Set 2 | souillac
# Processing Record 35 of Set 2 | zeya
# Processing Record 36 of Set 2 | kahului
# Processing Record 37 of Set 2 | tuktoyaktuk
# Processing Record 38 of Set 2 | sataua
# City not found. Skipping...
# Processing Record 39 of Set 2 | hobart
# Processing Record 40 of Set 2 | katsuura
# Processing Record 41 of Set 2 | matamoros
# Processing Record 42 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 43 of Set 2 | vaini
# Processing Record 44 of Set 2 | cape town
# Processing Record 45 of Set 2 | yulara
# Processing Record 46 of Set 2 | mar del plata
# Processing Record 47 of Set 2 | omboue
# Processing Record 48 of Set 2 | mount gambier
# Processing Record 49 of Set 2 | alta floresta
# Processing Record 50 of Set 2 | khatanga
# Processing Record 1 of Set 3 | nanortalik
# Processing Record 2 of Set 3 | svetlogorsk
# Processing Record 3 of Set 3 | namibe
# Processing Record 4 of Set 3 | adrar
# Processing Record 5 of Set 3 | avarua
# Processing Record 6 of Set 3 | presidencia roque saenz pena
# Processing Record 7 of Set 3 | santa lucia
# Processing Record 8 of Set 3 | paamiut
# Processing Record 9 of Set 3 | nongstoin
# Processing Record 10 of Set 3 | chuy
# Processing Record 11 of Set 3 | maumere
# Processing Record 12 of Set 3 | palabuhanratu
# City not found. Skipping...
# Processing Record 13 of Set 3 | dingle
# Processing Record 14 of Set 3 | te anau
# Processing Record 15 of Set 3 | wanxian
# Processing Record 16 of Set 3 | thompson
# Processing Record 17 of Set 3 | castro
# Processing Record 18 of Set 3 | chumikan
# Processing Record 19 of Set 3 | bredasdorp
# Processing Record 20 of Set 3 | prince rupert
# Processing Record 21 of Set 3 | kavieng
# Processing Record 22 of Set 3 | tiksi
# Processing Record 23 of Set 3 | weligama
# Processing Record 24 of Set 3 | bojnurd
# Processing Record 25 of Set 3 | faanui
# Processing Record 26 of Set 3 | camalu
# Processing Record 27 of Set 3 | jamestown
# Processing Record 28 of Set 3 | arraial do cabo
# Processing Record 29 of Set 3 | jurado
# Processing Record 30 of Set 3 | basi
# Processing Record 31 of Set 3 | lubao
# Processing Record 32 of Set 3 | jiaohe
# Processing Record 33 of Set 3 | manaus
# Processing Record 34 of Set 3 | sola
# Processing Record 35 of Set 3 | touros
# Processing Record 36 of Set 3 | pokhara
# Processing Record 37 of Set 3 | torbay
# Processing Record 38 of Set 3 | esil
# Processing Record 39 of Set 3 | rock springs
# Processing Record 40 of Set 3 | iqaluit
# Processing Record 41 of Set 3 | dikson
# Processing Record 42 of Set 3 | saint george
# Processing Record 43 of Set 3 | pevek
# Processing Record 44 of Set 3 | olden
# Processing Record 45 of Set 3 | khandbari
# Processing Record 46 of Set 3 | camabatela
# Processing Record 47 of Set 3 | norwich
# Processing Record 48 of Set 3 | lavrentiya
# Processing Record 49 of Set 3 | chilca
# Processing Record 50 of Set 3 | bitung
# Processing Record 1 of Set 4 | okhotsk
# Processing Record 2 of Set 4 | kerema
# Processing Record 3 of Set 4 | burica
# City not found. Skipping...
# Processing Record 4 of Set 4 | port hedland
# Processing Record 5 of Set 4 | lebu
# Processing Record 6 of Set 4 | along
# Processing Record 7 of Set 4 | makakilo city
# Processing Record 8 of Set 4 | hasaki
# Processing Record 9 of Set 4 | saint-philippe
# Processing Record 10 of Set 4 | oksbol
# Processing Record 11 of Set 4 | sinnamary
# Processing Record 12 of Set 4 | atuona
# Processing Record 13 of Set 4 | itarema
# Processing Record 14 of Set 4 | pringsewu
# Processing Record 15 of Set 4 | talnakh
# Processing Record 16 of Set 4 | mao
# Processing Record 17 of Set 4 | havre-saint-pierre
# Processing Record 18 of Set 4 | nikolskoye
# Processing Record 19 of Set 4 | boyolangu
# Processing Record 20 of Set 4 | bilibino
# Processing Record 21 of Set 4 | harper
# Processing Record 22 of Set 4 | shingu
# Processing Record 23 of Set 4 | bethel
# Processing Record 24 of Set 4 | hellvik
# Processing Record 25 of Set 4 | shimoda
# Processing Record 26 of Set 4 | charlestown
# Processing Record 27 of Set 4 | mahebourg
# Processing Record 28 of Set 4 | naze
# Processing Record 29 of Set 4 | pietermaritzburg
# Processing Record 30 of Set 4 | bibiani
# Processing Record 31 of Set 4 | agirish
# Processing Record 32 of Set 4 | clyde river
# Processing Record 33 of Set 4 | laizhou
# Processing Record 34 of Set 4 | walvis bay
# Processing Record 35 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 36 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 37 of Set 4 | goderich
# Processing Record 38 of Set 4 | santa cruz de tenerife
# Processing Record 39 of Set 4 | ahipara
# Processing Record 40 of Set 4 | fortuna
# Processing Record 41 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 42 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 43 of Set 4 | dharchula
# Processing Record 44 of Set 4 | naryan-mar
# Processing Record 45 of Set 4 | krasnoshchekovo
# Processing Record 46 of Set 4 | lipari
# Processing Record 47 of Set 4 | limon
# Processing Record 48 of Set 4 | acapulco
# Processing Record 49 of Set 4 | leningradskiy
# Processing Record 50 of Set 4 | mbandaka
# Processing Record 1 of Set 5 | sembakung
# Processing Record 2 of Set 5 | kiunga
# Processing Record 3 of Set 5 | norwalk
# Processing Record 4 of Set 5 | mentok
# City not found. Skipping...
# Processing Record 5 of Set 5 | marsaxlokk
# Processing Record 6 of Set 5 | kangaatsiaq
# Processing Record 7 of Set 5 | geraldton
# Processing Record 8 of Set 5 | constitucion
# Processing Record 9 of Set 5 | coffs harbour
# Processing Record 10 of Set 5 | kristianstad
# Processing Record 11 of Set 5 | nantucket
# Processing Record 12 of Set 5 | jinchang
# Processing Record 13 of Set 5 | utiroa
# City not found. Skipping...
# Processing Record 14 of Set 5 | tamiahua
# Processing Record 15 of Set 5 | ambulu
# Processing Record 16 of Set 5 | bundaberg
# Processing Record 17 of Set 5 | kaitangata
# Processing Record 18 of Set 5 | saint-louis
# Processing Record 19 of Set 5 | tromso
# Processing Record 20 of Set 5 | bubaque
# Processing Record 21 of Set 5 | fukue
# Processing Record 22 of Set 5 | riberalta
# Processing Record 23 of Set 5 | iquique
# Processing Record 24 of Set 5 | masaki
# Processing Record 25 of Set 5 | amahai
# Processing Record 26 of Set 5 | bagahanglad
# City not found. Skipping...
# Processing Record 27 of Set 5 | faya
# Processing Record 28 of Set 5 | saint anthony
# Processing Record 29 of Set 5 | poshekhonye
# Processing Record 30 of Set 5 | maungatapere
# Processing Record 31 of Set 5 | santa maria
# Processing Record 32 of Set 5 | ponta do sol
# Processing Record 33 of Set 5 | codrington
# Processing Record 34 of Set 5 | zyryanka
# Processing Record 35 of Set 5 | vao
# Processing Record 36 of Set 5 | caravelas
# Processing Record 37 of Set 5 | hilo
# Processing Record 38 of Set 5 | darhan
# Processing Record 39 of Set 5 | kallithiron
# Processing Record 40 of Set 5 | san joaquin
# Processing Record 41 of Set 5 | bengkulu
# Processing Record 42 of Set 5 | guayaramerin
# Processing Record 43 of Set 5 | ramhormoz
# Processing Record 44 of Set 5 | privokzalnyy
# City not found. Skipping...
# Processing Record 45 of Set 5 | airai
# Processing Record 46 of Set 5 | oranjemund
# Processing Record 47 of Set 5 | mogzon
# Processing Record 48 of Set 5 | kattivakkam
# Processing Record 49 of Set 5 | tumannyy
# City not found. Skipping...
# Processing Record 50 of Set 5 | alugan
# Processing Record 1 of Set 6 | karaton
# Processing Record 2 of Set 6 | cherskiy
# Processing Record 3 of Set 6 | marakkanam
# Processing Record 4 of Set 6 | hammerfest
# Processing Record 5 of Set 6 | jardim
# Processing Record 6 of Set 6 | wulanhaote
# City not found. Skipping...
# Processing Record 7 of Set 6 | kinston
# Processing Record 8 of Set 6 | greeneville
# Processing Record 9 of Set 6 | attawapiskat
# City not found. Skipping...
# Processing Record 10 of Set 6 | igrim
# Processing Record 11 of Set 6 | grand gaube
# Processing Record 12 of Set 6 | amot
# Processing Record 13 of Set 6 | truro
# Processing Record 14 of Set 6 | kresttsy
# Processing Record 15 of Set 6 | kieta
# Processing Record 16 of Set 6 | saskylakh
# Processing Record 17 of Set 6 | sisimiut
# Processing Record 18 of Set 6 | sao filipe
# Processing Record 19 of Set 6 | lompoc
# Processing Record 20 of Set 6 | east london
# Processing Record 21 of Set 6 | ukiah
# Processing Record 22 of Set 6 | victoria
# Processing Record 23 of Set 6 | aquidauana
# Processing Record 24 of Set 6 | anloga
# Processing Record 25 of Set 6 | umzimvubu
# City not found. Skipping...
# Processing Record 26 of Set 6 | pisco
# Processing Record 27 of Set 6 | quatre cocos
# Processing Record 28 of Set 6 | miami
# Processing Record 29 of Set 6 | margate
# Processing Record 30 of Set 6 | rudnaya pristan
# Processing Record 31 of Set 6 | numaran
# Processing Record 32 of Set 6 | liling
# Processing Record 33 of Set 6 | morondava
# Processing Record 34 of Set 6 | sembe
# Processing Record 35 of Set 6 | norman wells
# Processing Record 36 of Set 6 | cockburn town
# Processing Record 37 of Set 6 | chara
# Processing Record 38 of Set 6 | sentyabrskiy
# City not found. Skipping...
# Processing Record 39 of Set 6 | vila velha
# Processing Record 40 of Set 6 | bandrele
# Processing Record 41 of Set 6 | elbistan
# Processing Record 42 of Set 6 | warqla
# City not found. Skipping...
# Processing Record 43 of Set 6 | chiredzi
# Processing Record 44 of Set 6 | zhanaozen
# Processing Record 45 of Set 6 | pacific grove
# Processing Record 46 of Set 6 | bogorodsk
# Processing Record 47 of Set 6 | karlskrona
# Processing Record 48 of Set 6 | nelson bay
# Processing Record 49 of Set 6 | iquitos
# Processing Record 50 of Set 6 | vorobyevka
# Processing Record 1 of Set 7 | champerico
# Processing Record 2 of Set 7 | tual
# Processing Record 3 of Set 7 | jaguarao
# Processing Record 4 of Set 7 | lulea
# Processing Record 5 of Set 7 | srednekolymsk
# Processing Record 6 of Set 7 | iberia
# Processing Record 7 of Set 7 | sandnessjoen
# Processing Record 8 of Set 7 | ayorou
# Processing Record 9 of Set 7 | annau
# Processing Record 10 of Set 7 | port lincoln
# Processing Record 11 of Set 7 | manteca
# Processing Record 12 of Set 7 | tezu
# Processing Record 13 of Set 7 | brazzaville
# Processing Record 14 of Set 7 | doha
# Processing Record 15 of Set 7 | selaphum
# Processing Record 16 of Set 7 | anadyr
# Processing Record 17 of Set 7 | puerto leguizamo
# Processing Record 18 of Set 7 | beloha
# Processing Record 19 of Set 7 | hirara
# Processing Record 20 of Set 7 | abha
# Processing Record 21 of Set 7 | emerald
# Processing Record 22 of Set 7 | vaitupu
# City not found. Skipping...
# Processing Record 23 of Set 7 | antofagasta
# Processing Record 24 of Set 7 | dudinka
# Processing Record 25 of Set 7 | gamba
# Processing Record 26 of Set 7 | saint-jean-de-braye
# Processing Record 27 of Set 7 | wanning
# Processing Record 28 of Set 7 | tarabha
# Processing Record 29 of Set 7 | kyle of lochalsh
# City not found. Skipping...
# Processing Record 30 of Set 7 | botad
# Processing Record 31 of Set 7 | ulaangom
# Processing Record 32 of Set 7 | kalomo
# City not found. Skipping...
# Processing Record 33 of Set 7 | coihaique
# Processing Record 34 of Set 7 | klaksvik
# Processing Record 35 of Set 7 | chadan
# Processing Record 36 of Set 7 | coquimbo
# Processing Record 37 of Set 7 | praia
# Processing Record 38 of Set 7 | muscat
# Processing Record 39 of Set 7 | fairbanks
# Processing Record 40 of Set 7 | zambezi
# Processing Record 41 of Set 7 | whitehorse
# Processing Record 42 of Set 7 | makung
# City not found. Skipping...
# Processing Record 43 of Set 7 | posse
# Processing Record 44 of Set 7 | galiwinku
# City not found. Skipping...
# Processing Record 45 of Set 7 | iracoubo
# Processing Record 46 of Set 7 | kawalu
# Processing Record 47 of Set 7 | san angelo
# Processing Record 48 of Set 7 | moscow
# Processing Record 49 of Set 7 | changji
# Processing Record 50 of Set 7 | husavik
# Processing Record 1 of Set 8 | mega
# Processing Record 2 of Set 8 | alofi
# Processing Record 3 of Set 8 | oxchuc
# Processing Record 4 of Set 8 | buribay
# Processing Record 5 of Set 8 | anqing
# Processing Record 6 of Set 8 | marzuq
# Processing Record 7 of Set 8 | sorvag
# City not found. Skipping...
# Processing Record 8 of Set 8 | korem
# Processing Record 9 of Set 8 | san juan
# Processing Record 10 of Set 8 | olafsvik
# Processing Record 11 of Set 8 | rundu
# Processing Record 12 of Set 8 | tarakan
# Processing Record 13 of Set 8 | hanna
# Processing Record 14 of Set 8 | atar
# Processing Record 15 of Set 8 | san patricio
# Processing Record 16 of Set 8 | baturaja
# Processing Record 17 of Set 8 | flinders
# Processing Record 18 of Set 8 | teya
# Processing Record 19 of Set 8 | houma
# Processing Record 20 of Set 8 | bela
# Processing Record 21 of Set 8 | akdepe
# Processing Record 22 of Set 8 | christchurch
# Processing Record 23 of Set 8 | motygino
# Processing Record 24 of Set 8 | mooi river
# City not found. Skipping...
# Processing Record 25 of Set 8 | beringovskiy
# Processing Record 26 of Set 8 | port blair
# Processing Record 27 of Set 8 | lira
# Processing Record 28 of Set 8 | ilhabela
# Processing Record 29 of Set 8 | kavaratti
# Processing Record 30 of Set 8 | puerto madero
# Processing Record 31 of Set 8 | marsa matruh
# Processing Record 32 of Set 8 | zhitikara
# City not found. Skipping...
# Processing Record 33 of Set 8 | the pas
# Processing Record 34 of Set 8 | sur
# Processing Record 35 of Set 8 | qianan
# Processing Record 36 of Set 8 | venice
# Processing Record 37 of Set 8 | reinosa
# Processing Record 38 of Set 8 | romilly-sur-seine
# Processing Record 39 of Set 8 | san rafael
# Processing Record 40 of Set 8 | bargal
# City not found. Skipping...
# Processing Record 41 of Set 8 | cidreira
# Processing Record 42 of Set 8 | koutsouras
# Processing Record 43 of Set 8 | ndola
# Processing Record 44 of Set 8 | betong
# Processing Record 45 of Set 8 | severnoye
# Processing Record 46 of Set 8 | port moresby
# Processing Record 47 of Set 8 | los llanos de aridane
# Processing Record 48 of Set 8 | southbridge
# Processing Record 49 of Set 8 | chicama
# Processing Record 50 of Set 8 | conde
# Processing Record 1 of Set 9 | colares
# Processing Record 2 of Set 9 | huarmey
# Processing Record 3 of Set 9 | chokurdakh
# Processing Record 4 of Set 9 | maltahohe
# Processing Record 5 of Set 9 | provideniya
# Processing Record 6 of Set 9 | riorges
# Processing Record 7 of Set 9 | hokitika
# Processing Record 8 of Set 9 | tautira
# Processing Record 9 of Set 9 | monte gordo
# Processing Record 10 of Set 9 | marawi
# Processing Record 11 of Set 9 | komsomolskiy
# Processing Record 12 of Set 9 | bahar
# Processing Record 13 of Set 9 | campeche
# Processing Record 14 of Set 9 | elliot
# Processing Record 15 of Set 9 | jacareacanga
# Processing Record 16 of Set 9 | carndonagh
# Processing Record 17 of Set 9 | kharp
# Processing Record 18 of Set 9 | lucapa
# Processing Record 19 of Set 9 | rocha
# Processing Record 20 of Set 9 | vikhorevka
# Processing Record 21 of Set 9 | zhigansk
# Processing Record 22 of Set 9 | malampaka
# Processing Record 23 of Set 9 | meulaboh
# Processing Record 24 of Set 9 | colorado
# Processing Record 25 of Set 9 | vanimo
# Processing Record 26 of Set 9 | atka
# City not found. Skipping...
# Processing Record 27 of Set 9 | hope
# Processing Record 28 of Set 9 | pointe-noire
# Processing Record 29 of Set 9 | aswan
# Processing Record 30 of Set 9 | roverud
# Processing Record 31 of Set 9 | haapiti
# Processing Record 32 of Set 9 | coos bay
# Processing Record 33 of Set 9 | magrath
# Processing Record 34 of Set 9 | alyangula
# Processing Record 35 of Set 9 | tevaitoa
# Processing Record 36 of Set 9 | haines junction
# Processing Record 37 of Set 9 | ixtapa
# Processing Record 38 of Set 9 | gejiu
# Processing Record 39 of Set 9 | majholi
# Processing Record 40 of Set 9 | edd
# Processing Record 41 of Set 9 | leh
# Processing Record 42 of Set 9 | fort nelson
# Processing Record 43 of Set 9 | saleaula
# City not found. Skipping...
# Processing Record 44 of Set 9 | usinsk
# Processing Record 45 of Set 9 | port hardy
# Processing Record 46 of Set 9 | san javier
# Processing Record 47 of Set 9 | alexandria
# Processing Record 48 of Set 9 | george town
# Processing Record 49 of Set 9 | bonfim
# Processing Record 50 of Set 9 | padang
# Processing Record 1 of Set 10 | sao joao da barra
# Processing Record 2 of Set 10 | high level
# Processing Record 3 of Set 10 | labutta
# City not found. Skipping...
# Processing Record 4 of Set 10 | bac lieu
# Processing Record 5 of Set 10 | inhambane
# Processing Record 6 of Set 10 | mandalgovi
# Processing Record 7 of Set 10 | wagga wagga
# Processing Record 8 of Set 10 | asau
# Processing Record 9 of Set 10 | opuwo
# Processing Record 10 of Set 10 | broken hill
# Processing Record 11 of Set 10 | tura
# Processing Record 12 of Set 10 | yarada
# Processing Record 13 of Set 10 | aketi
# Processing Record 14 of Set 10 | ambovombe
# Processing Record 15 of Set 10 | zolotinka
# City not found. Skipping...
# Processing Record 16 of Set 10 | draguignan
# Processing Record 17 of Set 10 | dzerzhinsk
# Processing Record 18 of Set 10 | nanning
# Processing Record 19 of Set 10 | marcona
# City not found. Skipping...
# Processing Record 20 of Set 10 | basco
# Processing Record 21 of Set 10 | roald
# Processing Record 22 of Set 10 | tomatlan
# Processing Record 23 of Set 10 | boa vista
# Processing Record 24 of Set 10 | grand centre
# City not found. Skipping...
# Processing Record 25 of Set 10 | cayenne
# Processing Record 26 of Set 10 | linxia
# Processing Record 27 of Set 10 | meteti
# Processing Record 28 of Set 10 | berdigestyakh
# Processing Record 29 of Set 10 | la rioja
# Processing Record 30 of Set 10 | keelung
# Processing Record 31 of Set 10 | guabito
# Processing Record 32 of Set 10 | anage
# Processing Record 33 of Set 10 | binga
# Processing Record 34 of Set 10 | comodoro rivadavia
# Processing Record 35 of Set 10 | portland
# Processing Record 36 of Set 10 | arlit
# Processing Record 37 of Set 10 | kuche
# City not found. Skipping...
# Processing Record 38 of Set 10 | hornepayne
# Processing Record 39 of Set 10 | jinan
# Processing Record 40 of Set 10 | blackfoot
# Processing Record 41 of Set 10 | sioux lookout
# Processing Record 42 of Set 10 | kasra
# City not found. Skipping...
# Processing Record 43 of Set 10 | ballina
# Processing Record 44 of Set 10 | hailar
# Processing Record 45 of Set 10 | buala
# Processing Record 46 of Set 10 | khovu-aksy
# Processing Record 47 of Set 10 | getulio vargas
# Processing Record 48 of Set 10 | san cristobal
# Processing Record 49 of Set 10 | sibu
# Processing Record 50 of Set 10 | buchanan
# Processing Record 1 of Set 11 | yar-sale
# Processing Record 2 of Set 11 | takab
# Processing Record 3 of Set 11 | yabelo
# Processing Record 4 of Set 11 | prainha
# Processing Record 5 of Set 11 | fougamou
# Processing Record 6 of Set 11 | college
# Processing Record 7 of Set 11 | altay
# Processing Record 8 of Set 11 | cabedelo
# Processing Record 9 of Set 11 | nizhniy tsasuchey
# Processing Record 10 of Set 11 | flin flon
# Processing Record 11 of Set 11 | kalmunai
# Processing Record 12 of Set 11 | bagan
# Processing Record 13 of Set 11 | ituni
# City not found. Skipping...
# Processing Record 14 of Set 11 | bakchar
# Processing Record 15 of Set 11 | pangnirtung
# Processing Record 16 of Set 11 | paragominas
# Processing Record 17 of Set 11 | general roca
# Processing Record 18 of Set 11 | armidale
# Processing Record 19 of Set 11 | nogent-le-rotrou
# Processing Record 20 of Set 11 | khani
# Processing Record 21 of Set 11 | kerrville
# Processing Record 22 of Set 11 | petropavlovsk-kamchatskiy
# Processing Record 23 of Set 11 | freetown
# Processing Record 24 of Set 11 | kiruna
# Processing Record 25 of Set 11 | muros
# Processing Record 26 of Set 11 | poum
# Processing Record 27 of Set 11 | ucluelet
# Processing Record 28 of Set 11 | kyren
# Processing Record 29 of Set 11 | oistins
# Processing Record 30 of Set 11 | gao
# Processing Record 31 of Set 11 | raymond
# Processing Record 32 of Set 11 | takoradi
# Processing Record 33 of Set 11 | puerto escondido
# Processing Record 34 of Set 11 | hovd
# Processing Record 35 of Set 11 | toliary
# City not found. Skipping...
# Processing Record 36 of Set 11 | dryden
# Processing Record 37 of Set 11 | vysokogornyy
# Processing Record 38 of Set 11 | lolua
# City not found. Skipping...
# Processing Record 39 of Set 11 | itatiba
# Processing Record 40 of Set 11 | lac du bonnet
# Processing Record 41 of Set 11 | samana
# Processing Record 42 of Set 11 | anse-bertrand
# Processing Record 43 of Set 11 | maniitsoq
# Processing Record 44 of Set 11 | aleksandrovsk-sakhalinskiy
# Processing Record 45 of Set 11 | rantepao
# Processing Record 46 of Set 11 | bereda
# Processing Record 47 of Set 11 | mitu
# Processing Record 48 of Set 11 | kargil
# Processing Record 49 of Set 11 | nizwa
# Processing Record 50 of Set 11 | ormara
# Processing Record 1 of Set 12 | kem
# Processing Record 2 of Set 12 | klaeng
# Processing Record 3 of Set 12 | lao cai
# Processing Record 4 of Set 12 | barcelos
# Processing Record 5 of Set 12 | kapit
# Processing Record 6 of Set 12 | sibolga
# Processing Record 7 of Set 12 | ostersund
# Processing Record 8 of Set 12 | dumas
# Processing Record 9 of Set 12 | acarau
# Processing Record 10 of Set 12 | inegol
# Processing Record 11 of Set 12 | rawson
# Processing Record 12 of Set 12 | ambilobe
# Processing Record 13 of Set 12 | mirebalais
# Processing Record 14 of Set 12 | kamenka
# Processing Record 15 of Set 12 | wajir
# Processing Record 16 of Set 12 | price
# Processing Record 17 of Set 12 | mishelevka
# Processing Record 18 of Set 12 | rockport
# Processing Record 19 of Set 12 | avera
# Processing Record 20 of Set 12 | muisne
# Processing Record 21 of Set 12 | karratha
# Processing Record 22 of Set 12 | shorewood
# Processing Record 23 of Set 12 | mujiayingzi
# Processing Record 24 of Set 12 | myitkyina
# Processing Record 25 of Set 12 | novaya igirma
# Processing Record 26 of Set 12 | gayeri
# Processing Record 27 of Set 12 | gravelbourg
# Processing Record 28 of Set 12 | lomovka
# Processing Record 29 of Set 12 | honningsvag
# Processing Record 30 of Set 12 | tarbagatay
# Processing Record 31 of Set 12 | creston
# Processing Record 32 of Set 12 | mae sai
# Processing Record 33 of Set 12 | bengkalis
# City not found. Skipping...
# Processing Record 34 of Set 12 | goba
# Processing Record 35 of Set 12 | capelinha
# Processing Record 36 of Set 12 | bima
# Processing Record 37 of Set 12 | homer
# Processing Record 38 of Set 12 | susner
# Processing Record 39 of Set 12 | abu samrah
# Processing Record 40 of Set 12 | iskateley
# Processing Record 41 of Set 12 | sakakah
# Processing Record 42 of Set 12 | mwingi
# Processing Record 43 of Set 12 | korla
# Processing Record 44 of Set 12 | bajna
# Processing Record 45 of Set 12 | sawakin
# Processing Record 46 of Set 12 | vakhtan
# Processing Record 47 of Set 12 | wynyard
# Processing Record 48 of Set 12 | nezhinka
# Processing Record 49 of Set 12 | moindou
# Processing Record 50 of Set 12 | challans
# Processing Record 1 of Set 13 | gizo
# Processing Record 2 of Set 13 | keflavik
# Processing Record 3 of Set 13 | zaraza
# Processing Record 4 of Set 13 | kronshtadt
# Processing Record 5 of Set 13 | maceio
# Processing Record 6 of Set 13 | mezen
# Processing Record 7 of Set 13 | ayagoz
# Processing Record 8 of Set 13 | yaan
# Processing Record 9 of Set 13 | neuquen
# Processing Record 10 of Set 13 | sobolevo
# Processing Record 11 of Set 13 | netivot
# Processing Record 12 of Set 13 | honolulu
# Processing Record 13 of Set 13 | uruzgan
# Processing Record 14 of Set 13 | lodja
# Processing Record 15 of Set 13 | ngukurr
# City not found. Skipping...
# Processing Record 16 of Set 13 | duku
# Processing Record 17 of Set 13 | ampanihy
# Processing Record 18 of Set 13 | sisophon
# Processing Record 19 of Set 13 | marfino
# Processing Record 20 of Set 13 | port-gentil
# Processing Record 21 of Set 13 | sao domingos
# Processing Record 22 of Set 13 | seminole
# Processing Record 23 of Set 13 | pingzhuang
# Processing Record 24 of Set 13 | hearst
# Processing Record 25 of Set 13 | araouane
# Processing Record 26 of Set 13 | wahiawa
# Processing Record 27 of Set 13 | morant bay
# Processing Record 28 of Set 13 | tateyama
# Processing Record 29 of Set 13 | mapiripan
# Processing Record 30 of Set 13 | la romana
# Processing Record 31 of Set 13 | tarudant
# City not found. Skipping...
# Processing Record 32 of Set 13 | cervo
# Processing Record 33 of Set 13 | eureka
# Processing Record 34 of Set 13 | carroll
# Processing Record 35 of Set 13 | cap malheureux
# Processing Record 36 of Set 13 | livramento
# Processing Record 37 of Set 13 | wonthaggi
# Processing Record 38 of Set 13 | nguiu
# City not found. Skipping...
# Processing Record 39 of Set 13 | broome
# Processing Record 40 of Set 13 | san giovanni in fiore
# Processing Record 41 of Set 13 | kristiinankaupunki
# Processing Record 42 of Set 13 | auki
# Processing Record 43 of Set 13 | upata
# Processing Record 44 of Set 13 | port macquarie
# Processing Record 45 of Set 13 | gravdal
# Processing Record 46 of Set 13 | guelengdeng
# City not found. Skipping...
# Processing Record 47 of Set 13 | lisala
# Processing Record 48 of Set 13 | zhangye
# Processing Record 49 of Set 13 | gayny
# Processing Record 50 of Set 13 | awjilah
# Processing Record 1 of Set 14 | santa rosa
# Processing Record 2 of Set 14 | urucui
# Processing Record 3 of Set 14 | buraydah
# Processing Record 4 of Set 14 | saint-georges
# Processing Record 5 of Set 14 | neepawa
# Processing Record 6 of Set 14 | pyshchug
# Processing Record 7 of Set 14 | sampit
# Processing Record 8 of Set 14 | uarini
# Processing Record 9 of Set 14 | obregon
# Processing Record 10 of Set 14 | mattru
# Processing Record 11 of Set 14 | manokwari
# Processing Record 12 of Set 14 | goma
# Processing Record 13 of Set 14 | pueblo nuevo
# Processing Record 14 of Set 14 | tocopilla
# Processing Record 15 of Set 14 | kanniyakumari
# Processing Record 16 of Set 14 | henties bay
# Processing Record 17 of Set 14 | kaliua
# Processing Record 18 of Set 14 | coahuayana
# Processing Record 19 of Set 14 | xilitla
# Processing Record 20 of Set 14 | khilok
# Processing Record 21 of Set 14 | sitka
# Processing Record 22 of Set 14 | saint-augustin
# Processing Record 23 of Set 14 | mecca
# Processing Record 24 of Set 14 | wilmington island
# Processing Record 25 of Set 14 | rawlins
# Processing Record 26 of Set 14 | somova
# Processing Record 27 of Set 14 | sonneberg
# Processing Record 28 of Set 14 | gotsu
# Processing Record 29 of Set 14 | hamilton
# Processing Record 30 of Set 14 | arcachon
# Processing Record 31 of Set 14 | buenos aires
# Processing Record 32 of Set 14 | menongue
# Processing Record 33 of Set 14 | puro
# Processing Record 34 of Set 14 | mount pleasant
# Processing Record 35 of Set 14 | torbat-e jam
# Processing Record 36 of Set 14 | turukhansk
# Processing Record 37 of Set 14 | porto novo
# Processing Record 38 of Set 14 | sept-iles
# Processing Record 39 of Set 14 | bilma
# Processing Record 40 of Set 14 | taoudenni
# Processing Record 41 of Set 14 | petatlan
# Processing Record 42 of Set 14 | roswell
# Processing Record 43 of Set 14 | villarrica
# Processing Record 44 of Set 14 | ipojuca
# Processing Record 45 of Set 14 | deder
# Processing Record 46 of Set 14 | road town
# Processing Record 47 of Set 14 | madimba
# Processing Record 48 of Set 14 | datong
# Processing Record 49 of Set 14 | tabas
# Processing Record 50 of Set 14 | gazni
# City not found. Skipping...
# Processing Record 1 of Set 15 | wajima
# Processing Record 2 of Set 15 | vestmannaeyjar
# Processing Record 3 of Set 15 | mogadouro
# Processing Record 4 of Set 15 | astorga
# Processing Record 5 of Set 15 | viligili
# City not found. Skipping...
# Processing Record 6 of Set 15 | sechura
# Processing Record 7 of Set 15 | gohana
# Processing Record 8 of Set 15 | amuntai
# Processing Record 9 of Set 15 | sao pedro
# Processing Record 10 of Set 15 | la ronge
# Processing Record 11 of Set 15 | tibiri
# Processing Record 12 of Set 15 | sohbatpur
# Processing Record 13 of Set 15 | murwillumbah
# Processing Record 14 of Set 15 | czestochowa
# Processing Record 15 of Set 15 | norrtalje
# Processing Record 16 of Set 15 | temnikov
# Processing Record 17 of Set 15 | joao pinheiro
# Processing Record 18 of Set 15 | mehamn
# Processing Record 19 of Set 15 | golega
# Processing Record 20 of Set 15 | grande prairie
# Processing Record 21 of Set 15 | smidovich
# Processing Record 22 of Set 15 | dubai
# Processing Record 23 of Set 15 | salalah
# Processing Record 24 of Set 15 | saryshagan
# City not found. Skipping...
# Processing Record 25 of Set 15 | nemuro
# Processing Record 26 of Set 15 | preobrazheniye
# Processing Record 27 of Set 15 | tiznit
# Processing Record 28 of Set 15 | yining
# Processing Record 29 of Set 15 | colatina
# Processing Record 30 of Set 15 | san ramon
# Processing Record 31 of Set 15 | byron bay
# Processing Record 32 of Set 15 | megion
# Processing Record 33 of Set 15 | nara
# Processing Record 34 of Set 15 | samarai
# Processing Record 35 of Set 15 | grindavik
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
#convert the array of dictionaries to a dataframe
city_data_df = pd.DataFrame(city_data)
city_data_df.head()
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Iralaya      HN  15.0000  -83.2333     79.32        86          94
# 1     Hithadhoo      MV  -0.6000   73.0833     84.36        74          96
# 2   Port Alfred      ZA -33.5906   26.8910     67.26        52           0
# 3  Krasnoselkup      RU  65.7000   82.4667     20.75        73          80
# 4         Kapaa      US  22.0752 -159.3190     82.38        79         100
#
#    Wind Speed Current Description
# 0       12.12     overcast clouds
# 1       15.05     overcast clouds
# 2       10.02           clear sky
# 3        5.03       broken clouds
# 4       16.11     overcast clouds

# %%
city_data_df.to_csv("Weather_Database/WeatherPy_Database.csv")
